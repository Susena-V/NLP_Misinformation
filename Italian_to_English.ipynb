# %%
import pandas as pd

# %% [markdown]
# ## Setting up the Token for hf

# %%
from huggingface_hub import notebook_login

notebook_login()
# Always run this and copy paste your hf token

# %% [markdown]
# ## Documentation Code - NOT CHATGPT

# %%
from transformers import MarianMTModel, MarianTokenizer

src_text = [
    "So chi è il mio nemico.",
    "Tom è illetterato; non capisce assolutamente nulla."
]

model_name = "Helsinki-NLP/opus-mt-it-en"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
translated = model.generate(**tokenizer(src_text, return_tensors="pt", padding=True))

for t in translated:
    print( tokenizer.decode(t, skip_special_tokens=True) )

# expected output:
#     I know who my enemy is.
#     Tom is illiterate; he understands absolutely nothing.
# Out:
# I know who my enemy is.
# Tom is unlettered; he doesn't understand anything at all.

# %% [markdown]
# ## Restructuring - NO CHATGPT - DID THIS MYSELF FOR UNDERSTANDING THE CODE

# %%
# Properly structured MODEL Loading

#NOTE - I DID NOT USE CHATGPT BLINDLY


from transformers import MarianMTModel, MarianTokenizer


model_name = "Helsinki-NLP/opus-mt-it-en"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# %%
# This is the translator part
# Understand and make custom function

src_text = [
    "So chi è il mio nemico.",
    "Tom è illetterato; non capisce assolutamente nulla."
]

translated = model.generate(**tokenizer(src_text, return_tensors="pt", padding=True))

for t in translated:
    print( tokenizer.decode(t, skip_special_tokens=True) )
# Out:
# I know who my enemy is.
# Tom is unlettered; he doesn't understand anything at all.

# %%
##

# %% [markdown]
# ### Figure out how to add to dataframe - yourself

# %% [markdown]
# ## Load the data

# %%
data_tweets = pd.read_csv('/kaggle/input/tweet-data-game-on/Updated_Tweet_Data.csv')

# %%
data_tweets
# Out:
#      Unnamed: 0                   ID  \
# 0             0  1498022438398877704
# 1             1  1498003150414008322
# 2             2  1497887473862467584
# 3             3  1497838543619645441
# 4             4  1497639979534667783
# ..          ...                  ...
# 727         727  1535893068108513280
# 728         728  1535700719516405761
# 729         729  1535197417917882374
# 730         730  1534556711591235584
# 731         731  1534120505677971459
#
#                                                    URL   Type  Label  \
# 0    https://twitter.com/manuela_carloni/status/149...  tweet      1
# 1    https://twitter.com/Silvano05230100/status/149...  tweet      2
# 2    https://twitter.com/barbarameletto/status/1497...  tweet      2
# 3    https://twitter.com/_dani_ta_6/status/14978385...  tweet      2
# 4    https://twitter.com/GabrieleGranato/status/149...  tweet      2
# ..                                                 ...    ...    ...
# ...

# %%
data_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  732 non-null    int64
#  1   ID          732 non-null    int64
#  2   URL         732 non-null    object
#  3   Type        732 non-null    object
#  4   Label       732 non-null    int64
#  5   Content     732 non-null    object
#  6   Image_Name  480 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 40.2+ KB

# %%
data_tweets['Content']
# Out:
# 0      Dopo aver hackerato la tv di Stato sostituendo...
# 1      Error: Tweet could not be scraped (Page.wait_f...
# 2      #flowers #lovers\nFate l'amore non fate la gue...
# 3      Se solo tutti mostrassimo più amore e comprens...
# 4      Chi sono i soldati che vediamo nei video? Sono...
#                              ...
# 727    TUTTI UNITI CONTRO DRAGHI\nCONTRO LA GUERRA\nC...
# 728    Error: Tweet could not be scraped (Page.wait_f...
# 729    Error: Tweet could not be scraped (Page.wait_f...
# 730    Error: Tweet could not be scraped (Page.wait_f...
# 731    Error: Tweet could not be scraped (Page.wait_f...
# Name: Content, Length: 732, dtype: object

# %%
data_tweets_cleaned = data_tweets[~data_tweets['Content'].str.contains('Error: Tweet could not be scraped')]

# %%
data_tweets_cleaned
# Out:
#      Unnamed: 0                   ID  \
# 0             0  1498022438398877704
# 2             2  1497887473862467584
# 3             3  1497838543619645441
# 4             4  1497639979534667783
# 5             5  1497624763396546561
# ..          ...                  ...
# 718         718  1538486694701408256
# 721         721  1538254178413322241
# 722         722  1537840889749458946
# 726         726  1535923240710946816
# 727         727  1535893068108513280
#
#                                                    URL   Type  Label  \
# 0    https://twitter.com/manuela_carloni/status/149...  tweet      1
# 2    https://twitter.com/barbarameletto/status/1497...  tweet      2
# 3    https://twitter.com/_dani_ta_6/status/14978385...  tweet      2
# 4    https://twitter.com/GabrieleGranato/status/149...  tweet      2
# 5    https://twitter.com/nonleggerlo/status/1497624...  tweet      1
# ..                                                 ...    ...    ...
# ...

# %% [markdown]
# ## Creating Translation function custom

# %%
# src_text = [
#     "So chi è il mio nemico.",
#     "Tom è illetterato; non capisce assolutamente nulla."
# ]

# translated = model.generate(**tokenizer(src_text, return_tensors="pt", padding=True))

# for t in translated:
#     print( tokenizer.decode(t, skip_special_tokens=True) )

def translate_text(text):
  translated = model.generate(**tokenizer(text, return_tensors="pt", padding=True))
  return tokenizer.decode(translated[0],skip_special_tokens=True)

# %%
data_tweets_translated=data_tweets_cleaned

# %%
data_tweets_translated['Translated'] = data_tweets_cleaned['Content'].apply(translate_text)

# %%
data_tweets_translated['Translated']

# %%
data_tweets_translated.tocsv('Translated.csv')

# %% [markdown]
# ## shit Code - the model is terrible

# %%
# Another Trial

# The model is shit

# Use the token to access Mariam model

# from transformers import MarianMTModel, MarianTokenizer

# src_text = [
#     "So chi è il mio nemico.",
#     "Tom è illetterato; non capisce assolutamente nulla."
# ]
# model_name = "Helsinki-NLP/opus-mt-tc-big-it-en"

# tokenizer = MarianTokenizer.from_pretrained(model_name)
# model = MarianMTModel.from_pretrained(model_name)
# translated = model.generate(**tokenizer(src_text, return_tensors="pt", padding=True))

# for t in translated:
#     print( tokenizer.decode(t, skip_special_tokens=True) )

# expected output:
#     I know who my enemy is.
#     Tom is illiterate; he understands absolutely nothing.
